# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

# %%
def init_weights(shape):
    return tf.Variable(tf.random_normal(shape, stddev=0.01))

def model(X, w_h, w_o):
    h = tf.nn.sigmoid(tf.matmul(X, w_h)) # input 784, output 625
    return tf.matmul(h, w_o) # input 625, output 10

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
trX = mnist.train.images
trY = mnist.train.labels
teX = mnist.test.images
teY = mnist.test.labels
# Out:
# WARNING:tensorflow:From <ipython-input-2-22c39bb26779>:8: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/default/miniconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/default/miniconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/default/miniconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/default/miniconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/default/miniconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# def init_weights(shape):
#     return tf.Variable(tf.random_normal(shape, stddev=0.01))

# def model(X, w_h, w_o):
#     h = tf.nn.sigmoid(tf.matmul(X, w_h)) # this is a basic mlp, think 2 stacked logistic regressions
#     return tf.matmul(h, w_o) # note that we dont take the softmax at the end because our cost fn does that for us

# mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# trX, trY, teX, teY = mnist.train.images, mnist.train.labels, mnist.test.images, mnist.test.labels
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
X = tf.placeholder("float", [None, 784])
Y = tf.placeholder("float", [None, 10])
w_h = init_weights([784, 625])
w_o = init_weights([625, 10])
py_x = model(X, w_h, w_o)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=py_x, labels=Y))
train_op = tf.train.GradientDescentOptimizer(0.05).minimize(cost)
predict_op = tf.argmax(py_x, 1)

# %%
# X = tf.placeholder("float", [None, 784])
# Y = tf.placeholder("float", [None, 10])

# w_h = init_weights([784, 625]) # create symbolic variables
# w_o = init_weights([625, 10])

# py_x = model(X, w_h, w_o)

# cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=py_x, labels=Y)) # compute costs
# train_op = tf.train.GradientDescentOptimizer(0.05).minimize(cost) # construct an optimizer
# predict_op = tf.argmax(py_x, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(np.reshape(trX[10], [28, 28]))

# %%
# plt.imshow(np.reshape(trX[10], [28,28]))

# %%
# illustration of the batching mechanism
print('Total length of trX', len(trX))
for start, end in zip(range(0, len(trX), 128), range(128, len(trX)+1, 128)):
    print('Start index:', start, '| End index:', end)
# Out:
# Total length of trX 55000
# Start index: 0 | End index: 128
# Start index: 128 | End index: 256
# Start index: 256 | End index: 384
# Start index: 384 | End index: 512
# Start index: 512 | End index: 640
# Start index: 640 | End index: 768
# Start index: 768 | End index: 896
# Start index: 896 | End index: 1024
# Start index: 1024 | End index: 1152
# Start index: 1152 | End index: 1280
# Start index: 1280 | End index: 1408
# Start index: 1408 | End index: 1536
# Start index: 1536 | End index: 1664
# Start index: 1664 | End index: 1792
# Start index: 1792 | End index: 1920
# Start index: 1920 | End index: 2048
# Start index: 2048 | End index: 2176
# Start index: 2176 | End index: 2304
# Start index: 2304 | End index: 2432
# Start index: 2432 | End index: 2560
# Start index: 2560 | End index: 2688
# Start index: 2688 | End index: 2816
# Start index: 2816 | End index: 2944
# Start index: 2944 | End index: 3072
# Start index: 3072 | End index: 3200
# Start index: 3200 | End index: 3328
# Start index: 3328 | End index: 3456
# Start index: 3456 | End index: 3584
# Start index: 3584 | End index: 3712
# Start index: 3712 | End index: 3840
# Start index: 3840 | End index: 3968
# Start index: 3968 | End index: 4096
# Start index: 4096 | End index: 4224
# Start index: 4224 | End index: 4352
# Start index: 4352 | End index: 4480
# Start index: 4480 | End index: 4608
# Start index: 4608 | End index: 4736
# Start index: 4736 | End index: 4864
# Start index: 4864 | End index: 4992
# Start index: 4992 | End index: 5120
# Start index: 5120 | End index: 5248
# Start index: 5248 | End index: 5376
# Start index: 5376 | End index: 5504
# Start index: 5504 | End index: 5632
# Start index: 5632 | End index: 5760
# Start index: 5760 | End index: 5888
# Start index: 5888 | End index: 6016
# Start index: 6016 | End index: 6144
# Start index: 6144 | End index: 6272
# Start index: 6272 | End index: 6400
# Start index: 6400 | End index: 6528
# Start index: 6528 | End index: 6656
# Start index: 6656 | End index: 6784
# Start index: 6784 | End index: 6912
# Start index: 6912 | End index: 7040
# Start index: 7040 | End index: 7168
# Start index: 7168 | End index: 7296
# Start index: 7296 | End index: 7424
# Start index: 7424 | End index: 7552
# Start index: 7552 | End index: 7680
# Start index: 7680 | End index: 7808
# Start index: 7808 | End index: 7936
# Start index: 7936 | End index: 8064
# Start index: 8064 | End index: 8192
# Start index: 8192 | End index: 8320
# Start index: 8320 | End index: 8448
# Start index: 8448 | End index: 8576
# Start index: 8576 | End index: 8704
# Start index: 8704 | End index: 8832
# Start index: 8832 | End index: 8960
# Start index: 8960 | End index: 9088
# Start index: 9088 | End index: 9216
# Start index: 9216 | End index: 9344
# Start index: 9344 | End index: 9472
# Start index: 9472 | End index: 9600
# Start index: 9600 | End index: 9728
# Start index: 9728 | End index: 9856
# Start index: 9856 | End index: 9984
# Start index: 9984 | End index: 10112
# Start index: 10112 | End index: 10240
# Start index: 10240 | End index: 10368
# Start index: 10368 | End index: 10496
# Start index: 10496 | End index: 10624
# Start index: 10624 | End index: 10752
# Start index: 10752 | End index: 10880
# Start index: 10880 | End index: 11008
# Start index: 11008 | End index: 11136
# Start index: 11136 | End index: 11264
# Start index: 11264 | End index: 11392
# Start index: 11392 | End index: 11520
# Start index: 11520 | End index: 11648
# Start index: 11648 | End index: 11776
# Start index: 11776 | End index: 11904
# Start index: 11904 | End index: 12032
# Start index: 12032 | End index: 12160
# Start index: 12160 | End index: 12288
# Start index: 12288 | End index: 12416
# Start index: 12416 | End index: 12544
# Start index: 12544 | End index: 12672
# Start index: 12672 | End index: 12800
# Start index: 12800 | End index: 12928
# Start index: 12928 | End index: 13056
# Start index: 13056 | End index: 13184
# Start index: 13184 | End index: 13312
# Start index: 13312 | End index: 13440
# Start index: 13440 | End index: 13568
# Start index: 13568 | End index: 13696
# Start index: 13696 | End index: 13824
# Start index: 13824 | End index: 13952
# Start index: 13952 | End index: 14080
# Start index: 14080 | End index: 14208
# Start index: 14208 | End index: 14336
# Start index: 14336 | End index: 14464
# Start index: 14464 | End index: 14592
# Start index: 14592 | End index: 14720
# Start index: 14720 | End index: 14848
# Start index: 14848 | End index: 14976
# Start index: 14976 | End index: 15104
# Start index: 15104 | End index: 15232
# Start index: 15232 | End index: 15360
# Start index: 15360 | End index: 15488
# Start index: 15488 | End index: 15616
# Start index: 15616 | End index: 15744
# Start index: 15744 | End index: 15872
# Start index: 15872 | End index: 16000
# Start index: 16000 | End index: 16128
# Start index: 16128 | End index: 16256
# Start index: 16256 | End index: 16384
# Start index: 16384 | End index: 16512
# Start index: 16512 | End index: 16640
# Start index: 16640 | End index: 16768
# Start index: 16768 | End index: 16896
# Start index: 16896 | End index: 17024
# Start index: 17024 | End index: 17152
# Start index: 17152 | End index: 17280
# Start index: 17280 | End index: 17408
# Start index: 17408 | End index: 17536
# Start index: 17536 | End index: 17664
# Start index: 17664 | End index: 17792
# Start index: 17792 | End index: 17920
# Start index: 17920 | End index: 18048
# Start index: 18048 | End index: 18176
# Start index: 18176 | End index: 18304
# Start index: 18304 | End index: 18432
# Start index: 18432 | End index: 18560
# Start index: 18560 | End index: 18688
# Start index: 18688 | End index: 18816
# Start index: 18816 | End index: 18944
# Start index: 18944 | End index: 19072
# Start index: 19072 | End index: 19200
# Start index: 19200 | End index: 19328
# Start index: 19328 | End index: 19456
# Start index: 19456 | End index: 19584
# Start index: 19584 | End index: 19712
# Start index: 19712 | End index: 19840
# Start index: 19840 | End index: 19968
# Start index: 19968 | End index: 20096
# Start index: 20096 | End index: 20224
# Start index: 20224 | End index: 20352
# Start index: 20352 | End index: 20480
# Start index: 20480 | End index: 20608
# Start index: 20608 | End index: 20736
# Start index: 20736 | End index: 20864
# Start index: 20864 | End index: 20992
# Start index: 20992 | End index: 21120
# Start index: 21120 | End index: 21248
# Start index: 21248 | End index: 21376
# Start index: 21376 | End index: 21504
# Start index: 21504 | End index: 21632
# Start index: 21632 | End index: 21760
# Start index: 21760 | End index: 21888
# Start index: 21888 | End index: 22016
# Start index: 22016 | End index: 22144
# Start index: 22144 | End index: 22272
# Start index: 22272 | End index: 22400
# Start index: 22400 | End index: 22528
# Start index: 22528 | End index: 22656
# Start index: 22656 | End index: 22784
# Start index: 22784 | End index: 22912
# Start index: 22912 | End index: 23040
# Start index: 23040 | End index: 23168
# Start index: 23168 | End index: 23296
# Start index: 23296 | End index: 23424
# Start index: 23424 | End index: 23552
# Start index: 23552 | End index: 23680
# Start index: 23680 | End index: 23808
# Start index: 23808 | End index: 23936
# Start index: 23936 | End index: 24064
# Start index: 24064 | End index: 24192
# Start index: 24192 | End index: 24320
# Start index: 24320 | End index: 24448
# Start index: 24448 | End index: 24576
# Start index: 24576 | End index: 24704
# Start index: 24704 | End index: 24832
# Start index: 24832 | End index: 24960
# Start index: 24960 | End index: 25088
# Start index: 25088 | End index: 25216
# Start index: 25216 | End index: 25344
# Start index: 25344 | End index: 25472
# Start index: 25472 | End index: 25600
# Start index: 25600 | End index: 25728
# Start index: 25728 | End index: 25856
# Start index: 25856 | End index: 25984
# Start index: 25984 | End index: 26112
# Start index: 26112 | End index: 26240
# Start index: 26240 | End index: 26368
# Start index: 26368 | End index: 26496
# Start index: 26496 | End index: 26624
# Start index: 26624 | End index: 26752
# Start index: 26752 | End index: 26880
# Start index: 26880 | End index: 27008
# Start index: 27008 | End index: 27136
# Start index: 27136 | End index: 27264
# Start index: 27264 | End index: 27392
# Start index: 27392 | End index: 27520
# Start index: 27520 | End index: 27648
# Start index: 27648 | End index: 27776
# Start index: 27776 | End index: 27904
# Start index: 27904 | End index: 28032
# Start index: 28032 | End index: 28160
# Start index: 28160 | End index: 28288
# Start index: 28288 | End index: 28416
# Start index: 28416 | End index: 28544
# Start index: 28544 | End index: 28672
# Start index: 28672 | End index: 28800
# Start index: 28800 | End index: 28928
# Start index: 28928 | End index: 29056
# Start index: 29056 | End index: 29184
# Start index: 29184 | End index: 29312
# Start index: 29312 | End index: 29440
# Start index: 29440 | End index: 29568
# Start index: 29568 | End index: 29696
# Start index: 29696 | End index: 29824
# Start index: 29824 | End index: 29952
# Start index: 29952 | End index: 30080
# Start index: 30080 | End index: 30208
# Start index: 30208 | End index: 30336
# Start index: 30336 | End index: 30464
# Start index: 30464 | End index: 30592
# Start index: 30592 | End index: 30720
# Start index: 30720 | End index: 30848
# Start index: 30848 | End index: 30976
# Start index: 30976 | End index: 31104
# Start index: 31104 | End index: 31232
# Start index: 31232 | End index: 31360
# Start index: 31360 | End index: 31488
# Start index: 31488 | End index: 31616
# Start index: 31616 | End index: 31744
# Start index: 31744 | End index: 31872
# Start index: 31872 | End index: 32000
# Start index: 32000 | End index: 32128
# Start index: 32128 | End index: 32256
# Start index: 32256 | End index: 32384
# Start index: 32384 | End index: 32512
# Start index: 32512 | End index: 32640
# Start index: 32640 | End index: 32768
# Start index: 32768 | End index: 32896
# Start index: 32896 | End index: 33024
# Start index: 33024 | End index: 33152
# Start index: 33152 | End index: 33280
# Start index: 33280 | End index: 33408
# Start index: 33408 | End index: 33536
# Start index: 33536 | End index: 33664
# Start index: 33664 | End index: 33792
# Start index: 33792 | End index: 33920
# Start index: 33920 | End index: 34048
# Start index: 34048 | End index: 34176
# Start index: 34176 | End index: 34304
# Start index: 34304 | End index: 34432
# Start index: 34432 | End index: 34560
# Start index: 34560 | End index: 34688
# Start index: 34688 | End index: 34816
# Start index: 34816 | End index: 34944
# Start index: 34944 | End index: 35072
# Start index: 35072 | End index: 35200
# Start index: 35200 | End index: 35328
# Start index: 35328 | End index: 35456
# Start index: 35456 | End index: 35584
# Start index: 35584 | End index: 35712
# Start index: 35712 | End index: 35840
# Start index: 35840 | End index: 35968
# Start index: 35968 | End index: 36096
# Start index: 36096 | End index: 36224
# Start index: 36224 | End index: 36352
# Start index: 36352 | End index: 36480
# Start index: 36480 | End index: 36608
# Start index: 36608 | End index: 36736
# Start index: 36736 | End index: 36864
# Start index: 36864 | End index: 36992
# Start index: 36992 | End index: 37120
# Start index: 37120 | End index: 37248
# Start index: 37248 | End index: 37376
# Start index: 37376 | End index: 37504
# Start index: 37504 | End index: 37632
# Start index: 37632 | End index: 37760
# Start index: 37760 | End index: 37888
# Start index: 37888 | End index: 38016
# Start index: 38016 | End index: 38144
# Start index: 38144 | End index: 38272
# Start index: 38272 | End index: 38400
# Start index: 38400 | End index: 38528
# Start index: 38528 | End index: 38656
# Start index: 38656 | End index: 38784
# Start index: 38784 | End index: 38912
# Start index: 38912 | End index: 39040
# Start index: 39040 | End index: 39168
# Start index: 39168 | End index: 39296
# Start index: 39296 | End index: 39424
# Start index: 39424 | End index: 39552
# Start index: 39552 | End index: 39680
# Start index: 39680 | End index: 39808
# Start index: 39808 | End index: 39936
# Start index: 39936 | End index: 40064
# Start index: 40064 | End index: 40192
# Start index: 40192 | End index: 40320
# Start index: 40320 | End index: 40448
# Start index: 40448 | End index: 40576
# Start index: 40576 | End index: 40704
# Start index: 40704 | End index: 40832
# Start index: 40832 | End index: 40960
# Start index: 40960 | End index: 41088
# Start index: 41088 | End index: 41216
# Start index: 41216 | End index: 41344
# Start index: 41344 | End index: 41472
# Start index: 41472 | End index: 41600
# Start index: 41600 | End index: 41728
# Start index: 41728 | End index: 41856
# Start index: 41856 | End index: 41984
# Start index: 41984 | End index: 42112
# Start index: 42112 | End index: 42240
# Start index: 42240 | End index: 42368
# Start index: 42368 | End index: 42496
# Start index: 42496 | End index: 42624
# Start index: 42624 | End index: 42752
# Start index: 42752 | End index: 42880
# Start index: 42880 | End index: 43008
# Start index: 43008 | End index: 43136
# Start index: 43136 | End index: 43264
# Start index: 43264 | End index: 43392
# Start index: 43392 | End index: 43520
# Start index: 43520 | End index: 43648
# Start index: 43648 | End index: 43776
# Start index: 43776 | End index: 43904
# Start index: 43904 | End index: 44032
# Start index: 44032 | End index: 44160
# Start index: 44160 | End index: 44288
# Start index: 44288 | End index: 44416
# Start index: 44416 | End index: 44544
# Start index: 44544 | End index: 44672
# Start index: 44672 | End index: 44800
# Start index: 44800 | End index: 44928
# Start index: 44928 | End index: 45056
# Start index: 45056 | End index: 45184
# Start index: 45184 | End index: 45312
# Start index: 45312 | End index: 45440
# Start index: 45440 | End index: 45568
# Start index: 45568 | End index: 45696
# Start index: 45696 | End index: 45824
# Start index: 45824 | End index: 45952
# Start index: 45952 | End index: 46080
# Start index: 46080 | End index: 46208
# Start index: 46208 | End index: 46336
# Start index: 46336 | End index: 46464
# Start index: 46464 | End index: 46592
# Start index: 46592 | End index: 46720
# Start index: 46720 | End index: 46848
# Start index: 46848 | End index: 46976
# Start index: 46976 | End index: 47104
# Start index: 47104 | End index: 47232
# Start index: 47232 | End index: 47360
# Start index: 47360 | End index: 47488
# Start index: 47488 | End index: 47616
# Start index: 47616 | End index: 47744
# Start index: 47744 | End index: 47872
# Start index: 47872 | End index: 48000
# Start index: 48000 | End index: 48128
# Start index: 48128 | End index: 48256
# Start index: 48256 | End index: 48384
# Start index: 48384 | End index: 48512
# Start index: 48512 | End index: 48640
# Start index: 48640 | End index: 48768
# Start index: 48768 | End index: 48896
# Start index: 48896 | End index: 49024
# Start index: 49024 | End index: 49152
# Start index: 49152 | End index: 49280
# Start index: 49280 | End index: 49408
# Start index: 49408 | End index: 49536
# Start index: 49536 | End index: 49664
# Start index: 49664 | End index: 49792
# Start index: 49792 | End index: 49920
# Start index: 49920 | End index: 50048
# Start index: 50048 | End index: 50176
# Start index: 50176 | End index: 50304
# Start index: 50304 | End index: 50432
# Start index: 50432 | End index: 50560
# Start index: 50560 | End index: 50688
# Start index: 50688 | End index: 50816
# Start index: 50816 | End index: 50944
# Start index: 50944 | End index: 51072
# Start index: 51072 | End index: 51200
# Start index: 51200 | End index: 51328
# Start index: 51328 | End index: 51456
# Start index: 51456 | End index: 51584
# Start index: 51584 | End index: 51712
# Start index: 51712 | End index: 51840
# Start index: 51840 | End index: 51968
# Start index: 51968 | End index: 52096
# Start index: 52096 | End index: 52224
# Start index: 52224 | End index: 52352
# Start index: 52352 | End index: 52480
# Start index: 52480 | End index: 52608
# Start index: 52608 | End index: 52736
# Start index: 52736 | End index: 52864
# Start index: 52864 | End index: 52992
# Start index: 52992 | End index: 53120
# Start index: 53120 | End index: 53248
# Start index: 53248 | End index: 53376
# Start index: 53376 | End index: 53504
# Start index: 53504 | End index: 53632
# Start index: 53632 | End index: 53760
# Start index: 53760 | End index: 53888
# Start index: 53888 | End index: 54016
# Start index: 54016 | End index: 54144
# Start index: 54144 | End index: 54272
# Start index: 54272 | End index: 54400
# Start index: 54400 | End index: 54528
# Start index: 54528 | End index: 54656
# Start index: 54656 | End index: 54784
# Start index: 54784 | End index: 54912

# %%
# # Launch the graph in a session
# with tf.Session() as sess:
#     # you need to initialize all variables
#     tf.global_variables_initializer().run()

#     for i in range(100):
#         for start, end in zip(range(0, len(trX), 128), range(128, len(trX)+1, 128)):
#             sess.run(train_op, feed_dict={X: trX[start:end], Y: trY[start:end]})
#         if i % 10 == 0:
#             # print(sess.run(predict_op, feed_dict={X: teX}))
#             print(i, np.mean(np.argmax(teY, axis=1) == sess.run(predict_op, feed_dict={X: teX})))
# Out:
# 0 0.6862
# 10 0.9073
# 20 0.9186
# 30 0.9229
# 40 0.9272
# 50 0.9323
# 60 0.9393
# 70 0.9431
# 80 0.9484
# 90 0.952

# %%
# Launch the graph in a session
with tf.Session() as sess:
    # you need to initialize all variables
    tf.global_variables_initializer().run()

    for i in range(100):
        for start, end in zip(range(0, len(trX), 128), range(128, len(trX)+1, 128)):
            sess.run(train_op, feed_dict={X: trX[start:end], Y: trY[start:end]})
        if i % 10 == 0:
            # predictions by the network vs the labels or 'truth'
            print('Predictions:', sess.run(predict_op, feed_dict={X: teX}))
            print('Ground truth:', np.argmax(teY, axis=1))
            # compare both 
            print('Comparison:', np.argmax(teY, axis=1) == sess.run(predict_op, feed_dict={X: teX}))
            # take the mean of 0s or 1s for all predictions/labels comparisons 
            # -> the overall accuracy of the network
            print('Accuracy:', i, np.mean(np.argmax(teY, axis=1) == sess.run(predict_op, feed_dict={X: teX})))
            print('-'*30)
# Out:
# Predictions: [7 2 1 ... 4 6 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True False  True]
# Accuracy: 0 0.6956
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 10 0.9086
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 20 0.919
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 30 0.9228
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 40 0.9277
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 50 0.9341
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 60 0.94
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 70 0.9434
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 80 0.9477
# ------------------------------
# Predictions: [7 2 1 ... 4 5 6]
# Ground truth: [7 2 1 ... 4 5 6]
# Comparison: [ True  True  True ...  True  True  True]
# Accuracy: 90 0.9534
# ------------------------------

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    accuracy_over_time = []
    for i in range(100):
        # create indices so we can train on batches of 128 items
        for start, end in zip(range(0, len(trX), 128), range(128, len(trX)+1, 128)):
            sess.run(train_op, feed_dict={X: trX[start:end], Y: trY[start:end]})
        if i % 10 == 0:
            # Save accuracy data
            accuracy_over_time.append((i, np.mean(np.argmax(teY, axis=1) == sess.run(predict_op, feed_dict={X: teX}))))
            print('Iteration:', i, '| Accuracy: ', np.mean(np.argmax(teY, axis=1) == sess.run(predict_op, feed_dict={X: teX})))
    plt.figure()
    plt.xlabel('Iterations')
    plt.ylabel('Accuracy')
    plt.plot(*zip(*accuracy_over_time))
# Out:
# Iteration: 0 | Accuracy:  0.6878
# Iteration: 10 | Accuracy:  0.9076
# Iteration: 20 | Accuracy:  0.9186
# Iteration: 30 | Accuracy:  0.9228
# Iteration: 40 | Accuracy:  0.9276
# Iteration: 50 | Accuracy:  0.9335
# Iteration: 60 | Accuracy:  0.9386
# Iteration: 70 | Accuracy:  0.9426
# Iteration: 80 | Accuracy:  0.9482
# Iteration: 90 | Accuracy:  0.9526
